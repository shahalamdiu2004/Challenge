# %%
import pandas as pd
import numpy as np

data= pd.read_excel("Challenge-2-Last 3 Non Zero Sum.xlsx")

df= np.array(data)

result= df[ df != 0][-3:].sum()

result
# Out:
# np.int64(44)

# %%
import pandas as pd

data= pd.read_excel("Challenge-2-Last 3 Non Zero Sum.xlsx")

df= pd.DataFrame(data)

result= df[ df.iloc[:,0] != 0].tail(3).sum()

result
# Out:
# Data    44
# dtype: int64

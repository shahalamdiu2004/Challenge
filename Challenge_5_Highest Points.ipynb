# %%
import pandas as pd
df= pd.read_excel("Challenge-5-Highest Points.xlsx")

df["Total"]= df["Round 1"] +df["Round 2"] + df["Round 3"]

result= df[df["Total"]== df["Total"].max()]["Player"]
print(result.to_string(index=False))
# Out:
#  John
# Shine

# %%
import pandas as pd
df= pd.read_excel("Challenge-5-Highest Points.xlsx")

df["Total"]= df.iloc[:,1:].sum(axis=1)
result= df[df["Total"]== df["Total"].max()]["Player"]
print(result.to_string(index=False))
# Out:
#  John
# Shine

# %%
import pandas as pd
data= pd.read_excel("Challenge-1-Count Two Words.xlsx")
df= pd.DataFrame(data)
result= df[df.iloc[:,0].str.split().str.len()==2]
print (result.to_string(index=False))
# Out:
#              Name
#       Paul Hughes
#       Alan Murphy
#       Harold Cruz
#   Russell Mendoza
#      Frank Chavez
# Jonathan Martinez
#        Paul Scott
#       Carl Miller
